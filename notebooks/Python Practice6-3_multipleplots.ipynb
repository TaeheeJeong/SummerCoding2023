# %% [markdown]
# importing modules

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### generate sample data

# %%
x = np.random.normal(1, 10, 250)
y1 = 1.2 * x + 0.1* np.random.normal(0,1)
y2 = 1.7 * x + 0.1* np.random.normal(0,1)

# %% [markdown]
# ### multiple plots

# %%
# Function to plot
plt.plot(x,y1)
plt.plot(x,y2)
 
# function to show the plot
plt.show()

# %% [markdown]
# ### adding legends

# %%
# Function to plot
plt.plot(x,y1, label='sample1')
plt.plot(x,y2, label='sample2')

# adding legends
plt.legend()
 
# function to show the plot
plt.show()

# %% [markdown]
# ### adding labels and grid

# %%
# Function to plot
plt.plot(x,y1, label='sample1')
plt.plot(x,y2, label='sample2')

# adding legends
plt.legend()

# Adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")

# Adding the grid
plt.grid()


# function to show the plot
plt.show()

# %%
# To configure the integration and enable interactive mode use the %matplotlib
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# Function to plot
plt.plot(x,y1, label='sample1')
plt.plot(x,y2, label='sample2')

# adding legends
plt.legend()

# Adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")

# Adding the grid
plt.grid()


# function to show the plot
plt.show()
