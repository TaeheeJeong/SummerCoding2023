# %% [markdown]
# importing matplotlib/pyplot module

# %%
import matplotlib.pyplot as plt

# %%
# To configure the integration and enable interactive mode use the %matplotlib
#%matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ### line plot

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.plot(x,y)
 
# function to show the plot
plt.show()

# %% [markdown]
# ### scatter plot

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.scatter(x,y)
 
# function to show the plot
plt.show()

# %% [markdown]
# ### bar plot

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.bar(x,y)
 
# function to show the plot
plt.show()

# %% [markdown]
# ### histogram

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ### adding markers

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.plot(x,y, color='r', linestyle = 'dotted', marker='*', ms=20)
 
# function to show the plot
plt.show()

# %% [markdown]
# ### adding title and labels

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.scatter(x,y)

# Adding the title
plt.title("Simple Plot")
  
# Adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")

# function to show the plot
plt.show()

# %% [markdown]
# ### adding grid

# %%
# x-axis values
x = [5, 2, 9, 4, 7]
 
# Y-axis values
y = [10, 5, 8, 4, 2]
 
# Function to plot
plt.scatter(x,y)

# Adding the title
plt.title("Simple Plot")
  
# Adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")

# Adding the grid
plt.grid()

# function to show the plot
plt.show()
